# %%
import requests
from api_keys import weather_api_key, geoapify_key

# %%
skyPollu_url = 'https://s3.us-west-2.amazonaws.com/noirlab.edu.cee.prod/globeatnight/documents/GaN2022.json?AWSAccessKeyId=ASIAWX3YSJVTLLKEYBA2&Signature=2Ql4%2FxmFb3YSx48dE58jJNcPPnk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEAEaCXVzLXdlc3QtMiJHMEUCIQDb5Go%2BfWgyGSpDRRhy9heOympglA1Jc50dEmAdsTowSgIgAbD%2FfNxtl4QzsMmUqGoGMJ610%2BmlxyhL6XS%2FEseIFWQqhQUIGhABGgw0NjM1NzI0NTQ3NTgiDC3pPTL7ch0is6ny0yriBPj7sWmdFoHs2Or%2BSiVoxQlCrZIjpFx0iVvzjwVGhp5C8OW1xLB%2FfKIeNT%2Bo8FOw3%2FhFqDi%2FEibP2cTqzoHuAy9VkJrt6Exgi1tTS99X9CFbt0EeZ8ey99kdP95BDe5kqqlOepO46PV2pJOOhhKEdfl0A72XQzXZ1cwweMrXIns4rrVMINgCUS9CPwNbIElTTZfP343iWQIe5GaouX5tcXJdn0RylGwN9tWPlqSGm4IhgsC32%2FYFNDIpBpSGaPg97%2BLTkYRFvaTFi7h6jcdXtk57%2BAz4a4NNm1CftglPNjtbNYe%2FOnXMRX4bv7RIyjhWcp1ZqNFsQPDkFx3kgrdjnFzUVLd9I90%2FAQA7sZaadeuEHghg7AsS2eaMdaDdhnpWs%2BzEnYpRxT0a5GbqWktdoBtJjevKp3KUsIFcKXjih8wUbtIj6evXo9jxslCbtioSgRkE9I95esJ9jz9DYc%2BrHjiQjFdGHN33WH7OQFhrUIuzSUQ8TVjw2u973u0fatBooRasXipWrl1QM9l0VrEz0GdaYnhUAQ5G6wNy2jzoIUQR5515vy9WnPYQ1TCbTEwUWy%2BlItUGsg4LQxaQFcAdpBrlRA8OEdN7wJjAff3b0%2FEdFwMYV6hiSt6LIh5rtyNMYgKiwYDOCtap%2Bca2liyWzG0vS1EGbBPF1TStrypkWU8y%2FkYNftck8Lqds0kAZtQsg4aNUHcZrEk5Ca8V2%2BOVjwPlfMKkQyKh1uA0cuCWZXaea2vlZzj6LvDvdTphadofl5rDRNFIWf42nYuavRoNXQ1YQeRwm%2BUFD1xyedBSzyUiG6wwpcmgqQY6mgFHiT8h1OSmixjGahR2lQiSbPZ27eg3u0k0R%2F2V82RaRQVU2l6JRxKcVKYM0Lw%2FlXxoW%2FjZGjrgw0tKWSlJTlNW0Ou1rscSQv0EXMygZJk25fKYXkLWRoNrp%2BZ6kCaNOICJAyq8VBn9gU1122CtlncBGpWG4ye3mzrnWGc1Jj413p%2BVKuqXha8pwlEKo0GsFQ5zjHEZRLS4KZxM&Expires=1697134384'
sky_pollution = requests.get(skyPollu_url).json()

# %%
moon_URL = 'https://aa.usno.navy.mil/api/moon/phases/date?date=2023-10-24&nump=50'
moon_phases = requests.get(moon_URL).json()
moon_phases
# Out:
# {'apiversion': '4.0.1',
#  'day': 24,
#  'month': 10,
#  'numphases': 50,
#  'phasedata': [{'day': 28,
#    'month': 10,
#    'phase': 'Full Moon',
#    'time': '20:24',
#    'year': 2023},
#   {'day': 5,
#    'month': 11,
#    'phase': 'Last Quarter',
#    'time': '08:37',
#    'year': 2023},
#   {'day': 13, 'month': 11, 'phase': 'New Moon', 'time': '09:27', 'year': 2023},
#   {'day': 20,
#    'month': 11,
#    'phase': 'First Quarter',
#    'time': '10:50',
#    'year': 2023},
#   {'day': 27,
#    'month': 11,
#    'phase': 'Full Moon',
#    'time': '09:16',
#    'year': 2023},
#   {'day': 5,
#    'month': 12,
#    'phase': 'Last Quarter',
#    'time': '05:49',
#    'year': 2023},
#   {'day': 12, 'month': 12, 'phase': 'New Moon', 'time': '23:32', 'year': 2023},
#   {'day': 19,
#    'month': 12,
#    'phase': 'First Quarter',
#    'time': '18:39',
#    'year': 2023},
#   {'day': 27,
#    'month': 12,
#    'phase': 'Full Moon',
#    'time': '00:33',
#    'year': 2023},
# ...

# %%
weather_URL = 'https://api.openweathermap.org/data/2.5/weather?'

# get lat and long for best observation spots from sky_pollution, then plug them in here for weather
# for now just initialize at 0,0
lat = 0
lon = 0
weather_URL += f'lat={lat}&lon={lon}&appid={weather_api_key}'
weather = requests.get(weather_URL).json()

# %%
# at this point we need to figure out what data to keep from each file, then create a new json file
# for each url and join them together. There is probably a way to do this without needing
# to invoke pandas, but idk
